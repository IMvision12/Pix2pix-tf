# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from train import train_model
from dataset import train_data, test_data, decode_img
from model import generator, Discriminator
# Out:
# 2022-03-20 05:45:29.909734: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-20 05:45:29.992450: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-20 05:45:29.993140: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-20 05:45:29.994303: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-20 05:45:29.995262: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-20 05:45:29.995945: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-20 05:45:29.996590: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-20 05:45:31.801958: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-20 05:45:31.802834: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-20 05:45:31.803504: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-20 05:45:31.804070: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
TRAIN = "../input/pix2pix-dataset/facades/facades/train/*"
TEST = "../input/pix2pix-dataset/facades/facades/test/*"

# %%
train_ds = train_data(TRAIN)
test_ds = test_data(TEST)

# %%
plt.figure(figsize=(10, 10))
counter = 0
for sat, map_ in test_ds:
    plt.subplot(3, 3, counter + 1)
    plt.imshow(np.squeeze(sat) * 0.5 + 0.5)
    plt.title(sat.shape)
    plt.axis("off")
    counter+=1
    if counter==9: break
# Out:
# 2022-03-20 05:45:33.145622: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %%
plt.figure(figsize=(10, 10))
counter = 0
for sat, map_ in test_ds:
    plt.subplot(3, 3, counter + 1)
    plt.imshow(np.squeeze(map_)* 0.5 + 0.5)
    plt.title(sat.shape)
    plt.axis("off")
    counter+=1
    if counter==9: break

# %%
tf.config.run_functions_eagerly(True)
train_model(100, 2000, train_ds)
# Out:
# 2022-03-20 05:45:35.645845: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# Epochs:0 || Generator_Loss: 39.340 || Discriminator_Loss: 0.236
# Epochs:1 || Generator_Loss: 50.556 || Discriminator_Loss: 0.173
# Epochs:2 || Generator_Loss: 31.650 || Discriminator_Loss: 0.772
# Epochs:3 || Generator_Loss: 43.309 || Discriminator_Loss: 0.124
# Epochs:4 || Generator_Loss: 32.896 || Discriminator_Loss: 0.443
# Epochs:5 || Generator_Loss: 30.680 || Discriminator_Loss: 1.604
# Epochs:6 || Generator_Loss: 34.243 || Discriminator_Loss: 0.134
# Epochs:7 || Generator_Loss: 35.073 || Discriminator_Loss: 0.289
# Epochs:8 || Generator_Loss: 42.775 || Discriminator_Loss: 0.300
# Epochs:9 || Generator_Loss: 45.693 || Discriminator_Loss: 0.039
# Epochs:10 || Generator_Loss: 31.253 || Discriminator_Loss: 1.272
# Epochs:11 || Generator_Loss: 30.743 || Discriminator_Loss: 0.337
# Epochs:12 || Generator_Loss: 26.799 || Discriminator_Loss: 0.772
# Epochs:13 || Generator_Loss: 31.828 || Discriminator_Loss: 0.171
# Epochs:14 || Generator_Loss: 31.002 || Discriminator_Loss: 0.354
# Epochs:15 || Generator_Loss: 23.461 || Discriminator_Loss: 0.977
# Epochs:16 || Generator_Loss: 39.783 || Discriminator_Loss: 0.084
# Epochs:17 || Generator_Loss: 34.210 || Discriminator_Loss: 0.044
# Epochs:18 || Generator_Loss: 22.500 || Discriminator_Loss: 0.357
# Epochs:19 || Generator_Loss: 31.313 || Discriminator_Loss: 0.133
# Epochs:20 || Generator_Loss: 33.612 || Discriminator_Loss: 0.226
# Epochs:21 || Generator_Loss: 22.528 || Discriminator_Loss: 0.247
# Epochs:22 || Generator_Loss: 23.040 || Discriminator_Loss: 0.119
# Epochs:23 || Generator_Loss: 39.333 || Discriminator_Loss: 0.127
# Epochs:24 || Generator_Loss: 23.219 || Discriminator_Loss: 0.670
# Epochs:25 || Generator_Loss: 27.005 || Discriminator_Loss: 0.436
# Epochs:26 || Generator_Loss: 24.655 || Discriminator_Loss: 0.311
# Epochs:27 || Generator_Loss: 24.534 || Discriminator_Loss: 0.359
# Epochs:28 || Generator_Loss: 25.103 || Discriminator_Loss: 0.516
# Epochs:29 || Generator_Loss: 22.987 || Discriminator_Loss: 2.258
# Epochs:30 || Generator_Loss: 30.808 || Discriminator_Loss: 0.614
# Epochs:31 || Generator_Loss: 23.791 || Discriminator_Loss: 0.054
# Epochs:32 || Generator_Loss: 24.244 || Discriminator_Loss: 2.159
# Epochs:33 || Generator_Loss: 18.625 || Discriminator_Loss: 0.433
# Epochs:34 || Generator_Loss: 24.208 || Discriminator_Loss: 0.713
# Epochs:35 || Generator_Loss: 22.863 || Discriminator_Loss: 0.452
# Epochs:36 || Generator_Loss: 26.444 || Discriminator_Loss: 1.048
# Epochs:37 || Generator_Loss: 28.108 || Discriminator_Loss: 0.163
# Epochs:38 || Generator_Loss: 22.210 || Discriminator_Loss: 0.484
# Epochs:39 || Generator_Loss: 22.068 || Discriminator_Loss: 0.411
# Epochs:40 || Generator_Loss: 27.770 || Discriminator_Loss: 1.392
# Epochs:41 || Generator_Loss: 19.001 || Discriminator_Loss: 0.526
# Epochs:42 || Generator_Loss: 22.991 || Discriminator_Loss: 0.199
# Epochs:43 || Generator_Loss: 18.274 || Discriminator_Loss: 0.454
# Epochs:44 || Generator_Loss: 27.555 || Discriminator_Loss: 0.155
# Epochs:45 || Generator_Loss: 23.043 || Discriminator_Loss: 0.472
# Epochs:46 || Generator_Loss: 25.143 || Discriminator_Loss: 0.332
# Epochs:47 || Generator_Loss: 26.079 || Discriminator_Loss: 0.541
# Epochs:48 || Generator_Loss: 26.118 || Discriminator_Loss: 0.319
# Epochs:49 || Generator_Loss: 27.169 || Discriminator_Loss: 0.249
# Epochs:50 || Generator_Loss: 22.440 || Discriminator_Loss: 0.514
# Epochs:51 || Generator_Loss: 24.439 || Discriminator_Loss: 0.336
# Epochs:52 || Generator_Loss: 23.394 || Discriminator_Loss: 1.395
# Epochs:53 || Generator_Loss: 23.032 || Discriminator_Loss: 0.331
# Epochs:54 || Generator_Loss: 25.737 || Discriminator_Loss: 0.128
# Epochs:55 || Generator_Loss: 26.239 || Discriminator_Loss: 0.579
# Epochs:56 || Generator_Loss: 21.398 || Discriminator_Loss: 0.164
# Epochs:57 || Generator_Loss: 27.161 || Discriminator_Loss: 0.067
# Epochs:58 || Generator_Loss: 32.766 || Discriminator_Loss: 0.014
# Epochs:59 || Generator_Loss: 17.726 || Discriminator_Loss: 0.163
# Epochs:60 || Generator_Loss: 20.692 || Discriminator_Loss: 0.466
# Epochs:61 || Generator_Loss: 19.600 || Discriminator_Loss: 0.127
# Epochs:62 || Generator_Loss: 31.455 || Discriminator_Loss: 0.054
# Epochs:63 || Generator_Loss: 21.870 || Discriminator_Loss: 0.199
# Epochs:64 || Generator_Loss: 20.864 || Discriminator_Loss: 0.533
# Epochs:65 || Generator_Loss: 19.915 || Discriminator_Loss: 0.047
# Epochs:66 || Generator_Loss: 20.000 || Discriminator_Loss: 0.097
# Epochs:67 || Generator_Loss: 28.411 || Discriminator_Loss: 0.129
# Epochs:68 || Generator_Loss: 24.725 || Discriminator_Loss: 0.372
# Epochs:69 || Generator_Loss: 20.071 || Discriminator_Loss: 0.124
# Epochs:70 || Generator_Loss: 16.714 || Discriminator_Loss: 2.033
# Epochs:71 || Generator_Loss: 18.524 || Discriminator_Loss: 0.284
# Epochs:72 || Generator_Loss: 18.637 || Discriminator_Loss: 0.230
# Epochs:73 || Generator_Loss: 19.708 || Discriminator_Loss: 0.414
# Epochs:74 || Generator_Loss: 21.438 || Discriminator_Loss: 0.797
# Epochs:75 || Generator_Loss: 25.844 || Discriminator_Loss: 0.348
# Epochs:76 || Generator_Loss: 23.323 || Discriminator_Loss: 0.629
# Epochs:77 || Generator_Loss: 19.598 || Discriminator_Loss: 0.167
# Epochs:78 || Generator_Loss: 21.460 || Discriminator_Loss: 0.088
# Epochs:79 || Generator_Loss: 34.409 || Discriminator_Loss: 0.417
# Epochs:80 || Generator_Loss: 27.763 || Discriminator_Loss: 1.619
# Epochs:81 || Generator_Loss: 21.710 || Discriminator_Loss: 0.211
# Epochs:82 || Generator_Loss: 24.435 || Discriminator_Loss: 0.130
# Epochs:83 || Generator_Loss: 23.745 || Discriminator_Loss: 0.377
# Epochs:84 || Generator_Loss: 20.131 || Discriminator_Loss: 0.134
# Epochs:85 || Generator_Loss: 22.662 || Discriminator_Loss: 0.214
# Epochs:86 || Generator_Loss: 18.208 || Discriminator_Loss: 0.068
# Epochs:87 || Generator_Loss: 18.827 || Discriminator_Loss: 0.140
# Epochs:88 || Generator_Loss: 18.173 || Discriminator_Loss: 0.240
# Epochs:89 || Generator_Loss: 19.472 || Discriminator_Loss: 0.243
# Epochs:90 || Generator_Loss: 17.314 || Discriminator_Loss: 0.407
# Epochs:91 || Generator_Loss: 20.047 || Discriminator_Loss: 0.284
# Epochs:92 || Generator_Loss: 23.999 || Discriminator_Loss: 1.682
# Epochs:93 || Generator_Loss: 27.240 || Discriminator_Loss: 0.021
# Epochs:94 || Generator_Loss: 19.972 || Discriminator_Loss: 0.181
# Epochs:95 || Generator_Loss: 26.499 || Discriminator_Loss: 0.219
# Epochs:96 || Generator_Loss: 18.881 || Discriminator_Loss: 0.436
# Epochs:97 || Generator_Loss: 20.647 || Discriminator_Loss: 0.381
# Epochs:98 || Generator_Loss: 25.716 || Discriminator_Loss: 0.319
# Epochs:99 || Generator_Loss: 21.311 || Discriminator_Loss: 0.141
# 2022-03-20 11:58:44.707644: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.

# %%
def denormalize(img):
    img = (img + 1) * 127.5
    return img

# %%
Generator = tf.keras.models.load_model("/kaggle/working/generator.h5")

# %%
x, y = decode_img("../input/pix2pix-dataset/facades/facades/test/102.jpg")
preds = Generator.predict(tf.expand_dims(x, axis=0))

plt.figure(figsize=(16,9))
plt.subplot(131), plt.imshow(denormalize(x).numpy().astype('uint8'))
plt.subplot(132), plt.imshow(denormalize(y).numpy().astype('uint8'))
plt.subplot(133), plt.imshow(np.squeeze(denormalize(preds)).astype('uint8'))
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py:4212: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "

# %%
x, y = decode_img("../input/pix2pix-dataset/facades/facades/test/103.jpg")
preds = Generator.predict(tf.expand_dims(x, axis=0))

plt.figure(figsize=(16,9))
plt.subplot(131), plt.imshow(denormalize(x).numpy().astype('uint8'))
plt.subplot(132), plt.imshow(denormalize(y).numpy().astype('uint8'))
plt.subplot(133), plt.imshow(np.squeeze(denormalize(preds)).astype('uint8'))
plt.show()

# %%
x, y = decode_img("../input/pix2pix-dataset/facades/facades/test/19.jpg")
preds = Generator.predict(tf.expand_dims(x, axis=0))

plt.figure(figsize=(16,9))
plt.subplot(131), plt.imshow(denormalize(x).numpy().astype('uint8'))
plt.subplot(132), plt.imshow(denormalize(y).numpy().astype('uint8'))
plt.subplot(133), plt.imshow(np.squeeze(denormalize(preds)).astype('uint8'))
plt.show()

# %%
x, y = decode_img("../input/pix2pix-dataset/facades/facades/test/27.jpg")
preds = Generator.predict(tf.expand_dims(x, axis=0))

plt.figure(figsize=(16,9))
plt.subplot(131), plt.imshow(denormalize(x).numpy().astype('uint8'))
plt.subplot(132), plt.imshow(denormalize(y).numpy().astype('uint8'))
plt.subplot(133), plt.imshow(np.squeeze(denormalize(preds)).astype('uint8'))
plt.show()
